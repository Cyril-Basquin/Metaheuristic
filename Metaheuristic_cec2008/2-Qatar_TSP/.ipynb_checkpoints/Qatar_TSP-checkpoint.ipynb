26116.6667	,	51216.6667	,
26123.6111	,	51169.1667	,
26123.6111	,	51222.7778	,
26133.3333	,	51216.6667	,
26133.3333	,	51300.0000	,
26150.2778	,	51108.0556	
]

# %%
from math import sqrt
import numpy as np

# %% [markdown]
# ## Creation of the cost matrix

# %%
# Reshape the coordinates list
coordinates = np.reshape(cities, (int(len(cities)/2), 2))
coordinates.tolist()
x = coordinates[:,0]
y = coordinates[:,1]

# Create the matrix
cost_matrix = np.empty([len(x),len(y)])
for i in range(len(x)):
    for j in range(len(x)):
        if i == j:
            cost_matrix[i][j] = int(999999999)     
        else:
            cost_matrix[i][j] = int(sqrt((x[i]-x[j])**2 + (y[i]-y[j])**2))


cost_matrix = cost_matrix.tolist()

# %%
from __future__ import print_function
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from time import time

def create_data_model(cost_matrix):
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = cost_matrix # yapf: disable
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data


def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print('Objective: {} miles'.format(solution.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    trajectory = []
    route_distance = 0
    while not routing.IsEnd(index):
        plan_output += ' {} ->'.format(manager.IndexToNode(index))
        trajectory.append(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += ' {}\n'.format(manager.IndexToNode(index))
    print(plan_output)
    plan_output += 'Route distance: {}miles\n'.format(route_distance)
    return trajectory

# %%
# Instantiate the data problem.
data = create_data_model(cost_matrix)

# Create the routing index manager.
manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']), data['num_vehicles'], data['depot'])

# Create Routing Model.
routing = pywrapcp.RoutingModel(manager)


def distance_callback(from_index, to_index):
    """Returns the distance between the two nodes."""
    # Convert from routing variable Index to distance matrix NodeIndex.
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return data['distance_matrix'][from_node][to_node]

transit_callback_index = routing.RegisterTransitCallback(distance_callback)

# Define cost of each arc.
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Setting first solution heuristic.
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

t1 = time()
# Solve the problem.
solution = routing.SolveWithParameters(search_parameters)
t2 = time()

current_time = t2 -t1

# Print solution on console (and save the trajectory)
trajectory =  print_solution(manager, routing, solution)


# Close the trajectory loop
trajectory.append(trajectory[0])
# Out:
# Objective: 9966 miles
# Route for vehicle 0:
# 189 -> 191. Distance: 48.5. Total Distance: 6779.7
# 191 -> 190. Distance: 11.5. Total Distance: 6791.2
# 190 -> 188. Distance: 9.3. Total Distance: 6800.4
# 188 -> 183. Distance: 39.8. Total Distance: 6840.2
# 183 -> 176. Distance: 38.9. Total Distance: 6879.1
# 176 -> 180. Distance: 19.3. Total Distance: 6898.4
# 180 -> 187. Distance: 43.1. Total Distance: 6941.5
# 187 -> 192. Distance: 60.8. Total Distance: 7002.3
# 192 -> 184. Distance: 82.8. Total Distance: 7085.1
# 184 -> 179. Distance: 51.1. Total Distance: 7136.2
# 179 -> 177. Distance: 19.2. Total Distance: 7155.4
# 177 -> 167. Distance: 50.1. Total Distance: 7205.5
# 167 -> 164. Distance: 35.4. Total Distance: 7240.9
# 164 -> 158. Distance: 41.8. Total Distance: 7282.7
# 158 -> 157. Distance: 25.8. Total Distance: 7308.6
# 157 -> 161. Distance: 26.3. Total Distance: 7334.9
# 161 -> 166. Distance: 38.6. Total Distance: 7373.5
# 166 -> 169. Distance: 33.5. Total Distance: 7407.0
# 169 -> 170. Distance: 34.0. Total Distance: 7441.0
# 170 -> 165. Distance: 50.6. Total Distance: 7491.6
# 165 -> 159. Distance: 68.3. Total Distance: 7559.9
# 159 -> 147. Distance: 88.5. Total Distance: 7648.4
# 147 -> 142. Distance: 30.1. Total Distance: 7678.5
# 142 -> 134. Distance: 62.0. Total Distance: 7740.5
# 134 -> 128. Distance: 28.1. Total Distance: 7768.6
# 128 -> 132. Distance: 40.2. Total Distance: 7808.7
# 132 -> 127. Distance: 74.3. Total Distance: 7883.1
# 127 -> 123. Distance: 51.4. Total Distance: 7934.5
# 123 -> 122. Distance: 10.2. Total Distance: 7944.7
# 122 -> 119. Distance: 80.7. Total Distance: 8025.4
# 119 -> 120. Distance: 37.0. Total Distance: 8062.4
# 120 -> 116. Distance: 44.7. Total Distance: 8107.2
# 116 -> 115. Distance: 23.8. Total Distance: 8130.9
# 115 -> 114. Distance: 24.2. Total Distance: 8155.1
# 114 -> 111. Distance: 37.3. Total Distance: 8192.3
# 111 -> 109. Distance: 8.0. Total Distance: 8200.3
# 109 -> 99. Distance: 69.4. Total Distance: 8269.7
# 99 -> 83. Distance: 85.1. Total Distance: 8354.9
# 83 -> 67. Distance: 92.5. Total Distance: 8447.3
# 67 -> 65. Distance: 26.0. Total Distance: 8473.3
# 65 -> 72. Distance: 24.5. Total Distance: 8497.8
# 72 -> 66. Distance: 19.4. Total Distance: 8517.3
# 66 -> 60. Distance: 15.6. Total Distance: 8532.8
# 60 -> 50. Distance: 21.1. Total Distance: 8554.0
# 50 -> 38. Distance: 15.4. Total Distance: 8569.3
# 38 -> 46. Distance: 12.5. Total Distance: 8581.8
# 46 -> 57. Distance: 13.9. Total Distance: 8595.7
# 57 -> 55. Distance: 7.7. Total Distance: 8603.4
# 55 -> 52. Distance: 6.5. Total Distance: 8609.9
# 52 -> 51. Distance: 1.0. Total Distance: 8610.9
# 51 -> 53. Distance: 3.9. Total Distance: 8614.8
# 53 -> 54. Distance: 8.9. Total Distance: 8623.7
# 54 -> 48. Distance: 4.4. Total Distance: 8628.1
# 48 -> 49. Distance: 8.7. Total Distance: 8636.8
# 49 -> 41. Distance: 10.6. Total Distance: 8647.4
# 41 -> 43. Distance: 6.5. Total Distance: 8653.9
# 43 -> 45. Distance: 7.0. Total Distance: 8660.9
# 45 -> 47. Distance: 2.8. Total Distance: 8663.6
# 47 -> 40. Distance: 7.5. Total Distance: 8671.2
# 40 -> 37. Distance: 5.3. Total Distance: 8676.5
# 37 -> 42. Distance: 10.6. Total Distance: 8687.1
# 42 -> 39. Distance: 7.9. Total Distance: 8695.0
# 39 -> 33. Distance: 9.8. Total Distance: 8704.8
# 33 -> 30. Distance: 21.2. Total Distance: 8726.1
# 30 -> 34. Distance: 15.6. Total Distance: 8741.7
# 34 -> 31. Distance: 12.7. Total Distance: 8754.4
# 31 -> 29. Distance: 9.5. Total Distance: 8764.0
# 29 -> 18. Distance: 72.7. Total Distance: 8836.7
# 18 -> 14. Distance: 45.3. Total Distance: 8882.0
# 14 -> 11. Distance: 71.2. Total Distance: 8953.2
# 11 -> 9. Distance: 50.2. Total Distance: 9003.3
# 9 -> 8. Distance: 6.0. Total Distance: 9009.4
# 8 -> 4. Distance: 108.8. Total Distance: 9118.1
# 4 -> 2. Distance: 228.7. Total Distance: 9346.8
# 2 -> 1. Distance: 195.1. Total Distance: 9541.9
# 1 -> 3. Distance: 150.2. Total Distance: 9692.1
# 3 -> 0. Distance: 369.6. Total Distance: 10061.7

# %% [markdown]
# #### Plot of the result

# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

distance = solution.ObjectiveValue()

# Create a List to draw Cities connection
xlist=[]
ylist=[]
for i in range(len(trajectory)):
    ref_ = trajectory[i]
    xlist.append(x[ref_])
    ylist.append(y[ref_])
  
z = []
for i in range(len(x)):
    z.append(i)

# Create 2x2 sub plots
gs = gridspec.GridSpec(1, 2)

fig = plt.figure(figsize=(15,10))

# Some text about the problem and the result
ax1 = fig.add_subplot(gs[0, 0])
ax1.text(0.5, 0.9,"Function Name: {}".format("Qatar TSP (n=194)"), fontsize=18,  horizontalalignment='center', verticalalignment='center') 
ax1.text(0.5, 0.6,"Algorithm: {}".format("Google OR-Tools. Solver pywrapcp"), fontsize=14,  horizontalalignment='center', verticalalignment='center') 
ax1.text(0.5, 0.3,"Travel Distance: {}. \nOptimal distance: 9352\n\nRunningTime (in s): {:.1f}".format(distance, current_time), fontsize=14,  horizontalalignment='center', verticalalignment='center') 
ax1.tick_params(axis='x', which='both', bottom=False,  top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', left=False,  right=False, labelleft=False)

# Plot of the path to follow
ax2 = fig.add_subplot(gs[0, 1])
ax2.scatter(x, y, s=2, c= 'red', marker='.')
ax2.plot(xlist, ylist, linestyle='-')
ax2.set_xlabel("Latitude")
ax2.set_ylabel("Longitude")
ax2.axis('equal')

fig.savefig('Qatar_TSP.png')
