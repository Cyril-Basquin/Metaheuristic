# %%
import os

import numpy as np
import random
from time import time

# %%
original_path = os.getcwd()

# Import Objective function and the shifted global optimum (target and bias)
os.chdir('../problem')
from ipynb.fs.full.target_bias import target_bias
from ipynb.fs.full.objective_function import objective_function
from ipynb.fs.full.boundary_loader import boundary_loader
os.chdir(original_path)

# Import a homemade Genetic Algorithm
os.chdir('../algorithm')
from ipynb.fs.full.custom_GA import GA
os.chdir(original_path)

# %%
""" 
Arguments=
    -function: a callable function among:
        -Sphere
        -Schewfel
        -Rosenbrock
        -Rastrigin
        -Griewank
        -Ackley
"""

function_name = 'Rastrigin'

Problem_dimension = 50

# Number of run to get the better result
Run = 1

boundary = boundary_loader(function_name)
print('Boundary: +/- {}'.format(boundary))
# Out:
# Boundary: +/- 5

# %%
fitness_log_best = 99999

cr = 0.4
mr = 0.05


for i in range(1):
    t1 = time()
    fitness_log, best_candidate= GA(function = function_name
                                                ,pop_size = 100
                                               ,dimension = Problem_dimension
                                               ,lower_bound = -5.12
                                               ,upper_bound = 5.12
                                               ,iteration = 10000
                                               ,stop_rule = -999999999
                                               ,num_parents = 5
                                               ,maximization = False
                                               ,offspring_size = 100
                                               ,crossover_rate = cr
                                               ,crossover_type = 'SNP'
                                               ,mutation_intensity = 1
                                               ,mutation_rate = mr
                                               ,mutation_type = 'gaussian'
                                               ,mutation_decrease_time = 10
                                               ,mutation_decrease_intensity = 0.25
                                               ,mutation_jump = 50
                                              )
    t2 = time()

   # if np.min(fitness_log) < fitness_log_best:
    #    fitness_log_best = np.min(fitness_log)
     #   overall_best_candidate = best_candidate
      #  computation_time = t2 - t1
    computation_time = t2 - t1
# Out:
# Current iteration: 0. fitness: 690.5015545290664
# Current iteration: 100. fitness: -54.16696767694674
# Current iteration: 200. fitness: -54.529154874141454
# Current iteration: 300. fitness: -54.7299488410701
# Current iteration: 400. fitness: -54.94352341281052
# Current iteration: 500. fitness: -54.94352341281052
# Current iteration: 600. fitness: -54.94352341281052
# Current iteration: 700. fitness: -54.94352341281052
# Current iteration: 800. fitness: -54.94352341281052
# Current iteration: 900. fitness: -54.94352341281052
# Current iteration: 1000. fitness: -54.94352341281052
# Current iteration: 1100. fitness: -54.94352341281052
# Current iteration: 1200. fitness: -54.94352341281052
# Current iteration: 1300. fitness: -54.94352341281052
# Current iteration: 1400. fitness: -54.94352341281052
# Current iteration: 1500. fitness: -54.94352341281052
# Current iteration: 1600. fitness: -54.94352341281052
# Current iteration: 1700. fitness: -54.94352341281052
# Current iteration: 1800. fitness: -54.94352341281052
# Current iteration: 1900. fitness: -54.94352341281052
# Current iteration: 2000. fitness: -54.94352341281052
# Current iteration: 2100. fitness: -54.94352341281052
# Current iteration: 2200. fitness: -54.94352341281052
# Current iteration: 2300. fitness: -54.94352341281052
# Current iteration: 2400. fitness: -54.94352341281052
# Current iteration: 2500. fitness: -54.94352341281052
# Current iteration: 2600. fitness: -54.94352341281052
# Current iteration: 2700. fitness: -54.94352341281052
# Current iteration: 2800. fitness: -54.94352341281052
# Current iteration: 2900. fitness: -54.94352341281052
# Current iteration: 3000. fitness: -54.94352341281052
# Current iteration: 3100. fitness: -54.94352341281052
# Current iteration: 3200. fitness: -54.94352341281052
# Current iteration: 3300. fitness: -54.94352341281052
